# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("Laptop_Data.csv")
df.head()
# Out:
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    15.6    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1803.60
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq      CPU_model  \
# 0  Standard     2560  ...            Yes       Intel      2.3        Core i5
# 1  Standard     1440  ...             No       Intel      1.8        Core i5
# 2   Full HD     1920  ...             No       Intel      2.5  Core i5 7200U
# 3  Standard     2880  ...            Yes       Intel      2.7        Core i7
# 4  Standard     2560  ...            Yes       Intel      3.1        Core i5
#
# ...

# %%
df['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %%
df['CPU_model'].unique()
# Out:
# array(['Core i5', 'Core i5 7200U', 'Core i7', 'A9-Series 9420',
#        'Core i7 8550U', 'Core i5 8250U', 'Core i3 6006U', 'Core M m3',
#        'Core i7 7500U', 'Core i3 7100U', 'Atom x5-Z8350',
#        'Core i5 7300HQ', 'E-Series E2-9000e', 'Core i7 8650U',
#        'Atom x5-Z8300', 'E-Series E2-6110', 'A6-Series 9220',
#        'Celeron Dual Core N3350', 'Core i3 7130U', 'Core i7 7700HQ',
#        'Ryzen 1700', 'Pentium Quad Core N4200', 'Atom x5-Z8550',
#        'Celeron Dual Core N3060', 'FX 9830P', 'Core i7 7560U',
#        'E-Series 6110', 'Core i5 6200U', 'Core M 6Y75', 'Core i5 7500U',
#        'Core i7 6920HQ', 'Core i5 7Y54', 'Core i7 7820HK',
#        'Xeon E3-1505M V6', 'Core i7 6500U', 'E-Series 9000e',
#        'A10-Series A10-9620P', 'A6-Series A6-9220', 'Core i7 6600U',
#        'Celeron Dual Core 3205U', 'Core i7 7820HQ', 'A10-Series 9600P',
#        'Core i7 7600U', 'A8-Series 7410', 'Celeron Dual Core 3855U',
# ...

# %%
df.isnull().sum()
# Out:
# Company                 0
# Product                 0
# TypeName                0
# Inches                  0
# Ram                     0
# OS                      0
# Weight                  0
# Price_euros             0
# Screen                  0
# ScreenW                 0
# ScreenH                 0
# Touchscreen             0
# IPSpanel                0
# RetinaDisplay           0
# CPU_company             0
# CPU_freq                0
# CPU_model               0
# PrimaryStorage          0
# SecondaryStorage        0
# PrimaryStorageType      0
# SecondaryStorageType    0
# GPU_company             0
# GPU_model               0
# dtype: int64

# %%
df.describe()
# Out:
#             Inches          Ram       Weight  Price_euros      ScreenW  \
# count  1275.000000  1275.000000  1275.000000  1275.000000  1275.000000
# mean     15.022902     8.440784     2.040525  1134.969059  1900.043922
# std       1.429470     5.097809     0.669196   700.752504   493.346186
# min      10.100000     2.000000     0.690000   174.000000  1366.000000
# 25%      14.000000     4.000000     1.500000   609.000000  1920.000000
# 50%      15.600000     8.000000     2.040000   989.000000  1920.000000
# 75%      15.600000     8.000000     2.310000  1496.500000  1920.000000
# max      18.400000    64.000000     4.700000  6099.000000  3840.000000
#
#            ScreenH     CPU_freq  PrimaryStorage  SecondaryStorage
# count  1275.000000  1275.000000     1275.000000       1275.000000
# mean   1073.904314     2.302980      444.517647        176.069020
# std     283.883940     0.503846      365.537726        415.960655
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'Ram', 'OS', 'Weight',
#        'Price_euros', 'Screen', 'ScreenW', 'ScreenH', 'Touchscreen',
#        'IPSpanel', 'RetinaDisplay', 'CPU_company', 'CPU_freq', 'CPU_model',
#        'PrimaryStorage', 'SecondaryStorage', 'PrimaryStorageType',
#        'SecondaryStorageType', 'GPU_company', 'GPU_model'],
#       dtype='object')

# %%
Q1 = df['OS'].reset_index()
sns.countplot(x='OS', data=Q1)
plt.xlabel('Name Of Operating System')
plt.ylabel('Count Of Computers')
plt.title('Count Of Operatings Systems Computers')
plt.show()

# %%
Q2 = df['Company'].reset_index()
sns.countplot(x='Company', data=Q2)
plt.xlabel('Name Of Company')
plt.ylabel('Count Of Computer')
plt.title('Count Of Companies Computers')
plt.show()

# %%
Q2 = df['IPSpanel'].value_counts()
plt.pie(Q2, labels=Q2.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of IPSpanel')
plt.show()

# %%
Q4=df['Inches'].value_counts().reset_index()
sns.histplot(x='Inches' , data=Q4, palette='viridis')
plt.xlabel('Screen Size [Inche]')
plt.ylabel('Count Of Computers')
plt.title('Screen Size and Count of Computers')
plt.show()
# Out:
# C:\Users\MOMIN IZHAR\AppData\Local\Temp\ipykernel_19260\3751828331.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x='Inches' , data=Q4, palette='viridis')

# %%
Q5=df.groupby('Company')['Price_euros'].mean().head(7).reset_index()
sns.barplot(x='Company' , y='Price_euros' , data=Q5)
plt.xlabel('Company Name')
plt.ylabel('Computers Avg Price [Euros]')
plt.title('Avg Price of Companies Computers [TOP 7]')
plt.show()

# %%
Q6=df.groupby('RetinaDisplay')['Price_euros'].mean().reset_index()
sns.barplot(x='RetinaDisplay' , y='Price_euros' , data=Q6)
plt.xlabel('RetinaDisplay [Yes | NO]')
plt.ylabel('Computers Avg Price [Euros]')
plt.title('Retina Display Computers Avg Price')
plt.show()

# %%
Q7=df.groupby('Ram')['Price_euros'].mean().reset_index()
sns.lineplot(x='Ram' , y='Price_euros' , data=Q7)
plt.xlabel('Ram of computers')
plt.ylabel('Computers Avg Price [Euros]')
plt.title('Computers Avg Price [Euros] Based On RAM')
plt.show()

# %%
Q8=df.groupby('GPU_company')['Price_euros'].mean().reset_index()
sns.lineplot(x='GPU_company' , y='Price_euros' , data=Q8)
plt.xlabel('GPU company Name')
plt.ylabel('Computers Avg Price [Euros]')
plt.title('Computers Avg Price [Euros] Based On GPU')
plt.show()

# %%
Q9 = df['Touchscreen'].value_counts().reset_index()
Q5.columns = ['Touchscreen', 'Count']
sns.histplot(x='Touchscreen', weights='Count', data=Q5 , palette='viridis')

plt.xlabel('Screen Type [Touchscreen]')
plt.ylabel('Count of Computers')
plt.title('Count of Computers Based On Screen Type')
plt.show()
# Out:
# C:\Users\MOMIN IZHAR\AppData\Local\Temp\ipykernel_19260\384657890.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x='Touchscreen', weights='Count', data=Q5 , palette='viridis')

# %%
Q10=df.groupby('CPU_company')['CPU_freq'].mean().reset_index()
sns.lineplot(x='CPU_company', y='CPU_freq',data=Q10)
plt.xlabel('CPU Companies')
plt.ylabel('AVG CPU Frequency ')
plt.show()

# %%
Q11 = df['GPU_company'].value_counts().reset_index()
Q11.columns = ['GPU_company', 'Count']
sns.barplot(x='GPU_company', y='Count', data=Q11)
plt.xlabel('GPU Company')
plt.ylabel('Count of Computers')
plt.title('Distribution of Laptops by GPU Company')
plt.show()

# %%
Q12=df.groupby('Ram')['Price_euros'].mean().reset_index()
sns.scatterplot(x='Ram' , y='Price_euros' , data=Q12)
plt.xlabel('Ram Of The Computers')
plt.ylabel('Price in Euros')
plt.title('Prize Distribution Based On RAM')
# Out:
# Text(0.5, 1.0, 'Prize Distribution Based On RAM')

# %%
Q13=df.groupby('OS')['Weight'].mean().reset_index()
sns.barplot(x='OS', y='Weight', data=Q13)
plt.xlabel('Product')
plt.ylabel('Weight')
plt.title('Weight Distribution Across Products')
plt.show()

# %%
Q14=df['Price_euros'].value_counts().reset_index()
sns.histplot(x='Price_euros' , data=Q14, palette='viridis' ,bins=50)
plt.xlabel('Prize Of ')
plt.ylabel('Count Of Computers')
plt.show()
# Out:
# C:\Users\MOMIN IZHAR\AppData\Local\Temp\ipykernel_19260\3015239345.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(x='Price_euros' , data=Q14, palette='viridis' ,bins=50)

# %%
Q15=df['PrimaryStorage'].value_counts().reset_index()
sns.histplot(x='PrimaryStorage' , data=Q15)
plt.xlabel('Primary Storage Computer')
plt.ylabel('Count Of Computers')
plt.show()

# %%
Q15=df.groupby('Company')['CPU_freq'].mean().reset_index()
sns.boxplot(x='Company', y='CPU_freq', data=Q15)
plt.xlabel('Company')
plt.ylabel('CPU Frequency (GHz)')
plt.title('CPU Frequency Distribution Across Companies')
plt.show()

# %%
Q16=df.groupby('Ram')['CPU_freq'].mean().reset_index()
sns.boxplot(x='Ram', y='CPU_freq', data=Q16)
plt.xlabel( ' Ram Company')
plt.ylabel('CPU Frequency (GHz)')
plt.title('CPU Frequency Distribution Across RAM')
plt.show()

# %%
Q17 = df.groupby('Product')['Price_euros'].mean().head(7).reset_index()
sns.lineplot(x='Product', y='Price_euros', data=Q17)
plt.xlabel('Product')
plt.ylabel('AVG Price In Euros')
plt.title('Avg Price Of Product Top 7')
plt.xticks(rotation=45, ha='right')
plt.show()

Q17B = df.groupby('Product')['Price_euros'].mean().tail(7).reset_index()
sns.lineplot(x='Product', y='Price_euros', data=Q17B)
plt.xlabel('Product')
plt.ylabel('AVG Price In Euros')
plt.title('Avg Price Of Product Tail 7')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'Ram', 'OS', 'Weight',
#        'Price_euros', 'Screen', 'ScreenW', 'ScreenH', 'Touchscreen',
#        'IPSpanel', 'RetinaDisplay', 'CPU_company', 'CPU_freq', 'CPU_model',
#        'PrimaryStorage', 'SecondaryStorage', 'PrimaryStorageType',
#        'SecondaryStorageType', 'GPU_company', 'GPU_model'],
#       dtype='object')
